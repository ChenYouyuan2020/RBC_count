# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

from pythg.analysis import *
import os

#定义路径
flod=r"D:\self_file\RBC distribution test\Position1 1240nm excitation"
path_biotin = "1240 p90 HV120 Glavo 2.4 1024 z1 a1 P1_Z11_RGB_DAPI.tif"  
fluo_name = path_biotin[:-4]
path_biotin = os.path.join(flod,path_biotin) #荧光图片路径
print(fluo_name)
fluo = read_plot(path_biotin)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 1240 p90 HV120 Glavo 2.4 1024 z1 a1 P1_Z11_RGB_DAPI
# (1024, 1024)

# %%
#adjust min_area, max_area, make filter area/arc distribution looks like a gaussion.

contours, hierarchy, index_list, area_list, arc_list, degree_list, fluo_binary = \
chose_mask(fluo, min_area=100,max_area=600,min_degree=0.6, radius_hist_bin=30,erode_iterations=0)

# %%
# %matplotlib widget
# some cell with large hole will be removed as green color, preserve the cell less hole areas as red color. fluo image (blue color)

intensities, x_list, y_list, radius_list = plot_mask(fluo, fluo_binary,contours,index_list,hole_ratio=0.1)

save_file(flod, fluo_name,index_list,contours, intensities, area_list, arc_list, x_list, y_list, radius_list,bins=30)
# Out:
# 192 file has been saved
# 257 real cell numbers
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
